# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.washingtonpost.com/"
r = requests.get(url)
doc = r.text
soup = BeautifulSoup(doc,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="homepage layout_homepage rendering-context-www" itemscope="" itemtype="http://schema.org/ItemList" lang="en">
#  <head>
#   <script>
#    window.pbDeferredScripts=window.pbDeferredScripts||new Array;
#   </script>
#   <script id="_$cookiemonster">
#    (function(document,undefined){var wl={};wl.reg=[];wl.map=[];function CM(wlmap,wlreg){this.wl={map:wl.map.concat(wlmap||[]),reg:wl.reg.concat(wlreg||[])}}CM.prototype.ommNom=function(){return this.nom(true,undefined)};CM.prototype.allows=function(cookieKey){var yum=this.nom(false,[cookieKey]).indexOf(cookieKey)>-1;return!yum};CM.prototype.nom=function(deleteCookies,cookiesList){var unset=[];var domainkey=document.location.hostname.split("").reverse().join("").slice(0,18),dcookies=cookiesList||document.cookie.split(";"),
# ...

# %%
import newspaper
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-83b806c39519> in <module>()
# ----> 1 import newspaper
#
# /usr/local/lib/python3.5/dist-packages/newspaper/__init__.py in <module>()
#       8 __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
#       9
# ---> 10 from .api import (build, build_article, fulltext, hot, languages,
#      11                   popular_urls, Configuration as Config)
#      12 from .article import Article, ArticleException
#
# /usr/local/lib/python3.5/dist-packages/newspaper/api.py in <module>()
#      12 import feedparser
#      13
# ---> 14 from .article import Article
#      15 from .configuration import Configuration
#      16 from .settings import POPULAR_URLS, TRENDING_URL
#
# /usr/local/lib/python3.5/dist-packages/newspaper/article.py in <module>()
#      13
#      14 from . import images
# ---> 15 from . import network
# ...
